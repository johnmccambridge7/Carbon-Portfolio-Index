# %%
import pandas as pd
import requests, zipfile, io
# !pip install pyxlsb
import pyxlsb
from IPython.core.display import HTML
import yfinance as yf

import warnings
warnings.filterwarnings('ignore')

# Set up some default parameters for graphing
import matplotlib.pyplot as plt
from matplotlib import cycler
colour = "#00C2AB" # The default colour for the barcharts
colors = cycler('color', ['#4FBBA9', '#E56D13', '#D43A69','#25539f', '#88BB44', '#FFBBBB'])
plt.rc('axes', facecolor='#E6E6E6', edgecolor='none',
       axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 16}
plt.rc('font', **font)
plt.rc('legend', fancybox = True, framealpha=1, shadow=True, borderpad=1)
# Out:
# Requirement already satisfied: pyxlsb in /Users/dali/opt/anaconda3/lib/python3.9/site-packages (1.0.9)

# %%
# We will load in the sheets in the unzipped XLSX file that contain various kinds of direct emissions, from individual facilities and sectors/activities
ghg_fac = pd.read_excel("ghgp_data_2020.xlsx",
  skiprows = 1, # skip the first two rows, which are irrelevant
  header = 2, # the third row represents the header
  converters={'Primary NAICS Code':str}, # read the NAICS codes as strings
  sheet_name = ["Direct Emitters", "Onshore Oil & Gas Prod.", "Gathering & Boosting", 
    "Transmission Pipelines", "LDC - Direct Emissions", "SF6 from Elec. Equip.", "Suppliers"]) 

# We will also load in a file that tells us about the type of industry each facility is classified as
naics = pd.read_excel("https://www.census.gov/naics/2017NAICS/6-digit_2017_Codes.xlsx",
  header = 0, # the row that represents the header
  converters={'2017 NAICS Code':str,'2017 NAICS Title':str}
)
naics=naics[["2017 NAICS Code", "2017 NAICS Title"]]

# %%
ghg_fac["Suppliers"]["Emissions (tCO2e)"] = pd.to_numeric(ghg_fac["Suppliers"]["GHG Quantity Associated with Coal-based liquid fuel production"], errors='coerce').fillna(0) + \
  pd.to_numeric(ghg_fac["Suppliers"]["GHG Quantity Associated with Petroleum Products Produced"], errors='coerce').fillna(0) + \
  pd.to_numeric(ghg_fac["Suppliers"]["GHG Quantity Associated with Petroleum Products Imported"], errors='coerce').fillna(0) + \
  pd.to_numeric(ghg_fac["Suppliers"]["GHG Quantity Associated with Petroleum Products Exported"], errors='coerce').fillna(0) + \
  pd.to_numeric(ghg_fac["Suppliers"]["GHG Quantity Associated with Natural Gas Supply"], errors='coerce').fillna(0) + \
  pd.to_numeric(ghg_fac["Suppliers"]["GHG Quantity Associated with Natural Gas Liquids Supply"], errors='coerce').fillna(0) + \
  pd.to_numeric(ghg_fac["Suppliers"]["GHG Quantity Associated with CO2 Supply "], errors='coerce').fillna(0)

emissions_field_names = {
    "Direct Emitters": "Total reported direct emissions",
    "Onshore Oil & Gas Prod.": "Total reported emissions from Onshore Oil & Gas Production ",
    "Gathering & Boosting": "Total reported emissions from Gathering & Boosting",
    "Transmission Pipelines": "Total reported direct emissions from Transmission Pipelines",
    "LDC - Direct Emissions": "Total reported direct emissions from Local Distribution Companies",
    "SF6 from Elec. Equip.": "Total reported direct emissions from Electrical Equipment Use"
}

fac_directemitters_data = pd.DataFrame([], columns=["Facility", "Name", "Primary NAICS Code", "Emissions (tCO2e)"]) 
fac_suppliers_data = pd.DataFrame(ghg_fac["Suppliers"]) 

for key in emissions_field_names.keys():
  dump = ghg_fac[key]
  dump = dump[["Facility Id", "Facility Name", "Primary NAICS Code", emissions_field_names[key]]]
  dump = dump.rename(columns={"Facility Id": "Facility", "Facility Name": "Name", "Primary NAICS Code": "2017 NAICS Code", emissions_field_names[key]:"Emissions (tCO2e)"})
  dump["Emissions (tCO2e)"] = pd.to_numeric(dump["Emissions (tCO2e)"])
  fac_directemitters_data= fac_directemitters_data.append(dump)

fac_directemitters_data = fac_directemitters_data.groupby(by=["Facility", "Name", "2017 NAICS Code"]).sum().reset_index() #For presentation purposes, we'll add in the facility name
fac_suppliers_data=fac_suppliers_data.rename(columns={"Facility Id": "Facility", "Facility Name": "Name", "Primary NAICS Code": "2017 NAICS Code"})
fac_suppliers_data = fac_suppliers_data[["Facility", "Name", "2017 NAICS Code", "Emissions (tCO2e)"]]
fac_directemitters_data['2017 NAICS Code']=fac_directemitters_data['2017 NAICS Code'].astype(str)

# Look up industry information
fac_directemitters_data = fac_directemitters_data.merge(naics, on="2017 NAICS Code")
fac_suppliers_data = fac_suppliers_data.merge(naics, on="2017 NAICS Code")

# %%
url = "https://www.epa.gov/system/files/other-files/2021-10/ghgp_data_parent_company_10_2021.xlsb"
parents = pd.read_excel(url, engine='pyxlsb', sheet_name="2020", nrows=9144) # 9144 non-header rows in this file as of Nov 2021.
parents["PARENT COMPANY NAME"] = parents["PARENT COMPANY NAME"].str.upper() # Standardize company names to uppercase - sometimes EPA allows company names to be reported in upper and lower case, which intereferes with our ability to aggregate them
parents
# Out:
#       GHGRP FACILITY ID  FRS ID (FACILITY)  REPORTING YEAR  \
# 0               1000001       1.100005e+11            2020
# 1               1000002       1.100412e+11            2020
# 2               1000003       1.100015e+11            2020
# 3               1000005       1.100005e+11            2020
# 4               1000007       1.100070e+11            2020
# ...                 ...                ...             ...
# 9139            1014033                NaN            2020
# 9140            1014041                NaN            2020
# 9141            1014043                NaN            2020
# 9142            1014044       1.100626e+11            2020
# 9143            1014063                NaN            2020
#
#                                        FACILITY NAME  \
# 0                    PSE Ferndale Generating Station
# 1                        Ardagh Glass Inc. (Dunkirk)
# 2                      Ardagh Glass Inc. (Henderson)
# 3                         Ardagh Glass Inc. (Madera)
# 4     AMERICAN GYPSUM - BERNALILLO (WALLBOARD) PLANT
# ...                                              ...
# 9139              AW PRODUCT SALES AND MARKETING INC
# 9140                                     Bluon, Inc.
# 9141                            RAMJ Enterprises Inc
# 9142                    Wilhelmsen Ships Service Inc
# 9143     Transocean Offshore Deepwater Drilling Inc.
#
#                    FACILITY ADDRESS FACILITY CITY FACILITY STATE  \
# 0            5105 LAKE TERRELL ROAD      FERNDALE             WA
# 1              524 E. CENTER STREET       DUNKIRK             IN
# 2                    620 Facet Road     Henderson             NC
# 3     24441 AVENUE 12 & ROAD 24 1/2        MADERA             CA
# 4                    1000 N HILL RD    BERNALILLO             NM
# ...                             ...           ...            ...
# 9139   204 E. 2nd Avenue, Unit #343     San Mateo             CA
# 9140                      18 Bunsen        Irvine             CA
# 9141         4912 W KNOX ST STE 100         Tampa             FL
# 9142            9400 New Century Dr      Pasadena             TX
# 9143           1414 Enclave Parkway       Houston             TX
#
#       FACILITY ZIP  FACILITY COUNTY  \
# 0            98248   WHATCOM COUNTY
# 1            47336       JAY COUNTY
# 2            27537     VANCE COUNTY
# 3            93637    MADERA COUNTY
# 4            87004  SANDOVAL COUNTY
# ...            ...              ...
# 9139         94401              NaN
# 9140         92618              NaN
# 9141         33634              NaN
# 9142         77507    HARRIS COUNTY
# 9143         77077              NaN
#
#                              PARENT COMPANY NAME  \
# 0                             PUGET HOLDINGS LLC
# 1                               ARDAGH GLASS INC
# 2                               ARDAGH GLASS INC
# 3                               ARDAGH GLASS INC
# 4                            EAGLE MATERIALS INC
# ...                                          ...
# 9139                         AW DISTRIBUTING INC
# 9140                                   BLUON INC
# 9141                        RAMJ ENTERPRISES INC
# 9142                    WILHELMSEN SHIPS SERVICE
# 9143  TRANSOCEAN OFFSHORE DEEPWATER DRILLING INC
#
#           PARENT CO. STREET ADDRESS PARENT CO. CITY PARENT CO. STATE  \
# 0                      PO Box 97034        Bellevue               WA
# 1                1209 Orange Street      Wilmington               DE
# 2                1209 Orange Street      Wilmington               DE
# 3                1209 Orange Street      Wilmington               DE
# 4     5960 Berkshire Lane Suite 800          Dallas               TX
# ...                             ...             ...              ...
# 9139   204 E. 2nd Avenue, Unit #343       San Mateo               CA
# 9140                      18 Bunsen          Irvine               CA
# 9141                 4912 W KNOX ST           Tampa               FL
# 9142           9400 New Century Dr.        Pasadena               TX
# 9143              1414 Enclave Pwky         Houston               TX
#
#      PARENT CO. ZIP  PARENT CO. PERCENT OWNERSHIP  FACILITY NAICS CODE
# 0             98009                         100.0               221112
# 1             19801                         100.0               327213
# 2             19801                         100.0               327213
# 3             19801                         100.0               327213
# 4             75225                         100.0               327420
# ...             ...                           ...                  ...
# 9139          94401                         100.0               522293
# 9140          92618                         100.0               424690
# 9141          33634                         100.0               425120
# 9142          77507                         100.0               484220
# 9143          77077                         100.0               213111
#
# [9144 rows x 16 columns]

# %%
join_emitters = fac_directemitters_data.set_index("Facility").join(parents.set_index('GHGRP FACILITY ID'))
join_suppliers = fac_suppliers_data.set_index("Facility").join(parents.set_index('GHGRP FACILITY ID'))

# %%
plt.hist(join_suppliers['Emissions (tCO2e)'])
# Out:
# (array([987.,  77.,  33.,  17.,  13.,   6.,   1.,   3.,   2.,   2.]),
#  array([       0.        ,  8468430.17350562, 16936860.34701124,
#         25405290.52051686, 33873720.69402248, 42342150.8675281 ,
#         50810581.04103373, 59279011.21453935, 67747441.38804497,
#         76215871.56155059, 84684301.7350562 ]),
#  <BarContainer object of 10 artists>)

# %%
nas_s = join_suppliers.loc[join_suppliers["Emissions (tCO2e)"]  == 0]

# %%
nas_s

# %%
nas_s['PARENT COMPANY NAME']
# Out:
# 1000035                             THE ANDERSONS INC
# 1000035                       MARATHON PETROLEUM CORP
# 1000035                       MARATHON PETROLEUM CORP
# 1000039                           GENERAL ELECTRIC CO
# 1000158     ASCEND PERFORMANCE MATERIALS HOLDINGS INC
#                               ...
# 1014033                           AW DISTRIBUTING INC
# 1014041                                     BLUON INC
# 1014043                          RAMJ ENTERPRISES INC
# 1014044                      WILHELMSEN SHIPS SERVICE
# 1014063    TRANSOCEAN OFFSHORE DEEPWATER DRILLING INC
# Name: PARENT COMPANY NAME, Length: 364, dtype: object

# %%
join_emitters["PARENT EMISSIONS AMT"] = join_emitters['Emissions (tCO2e)'] * join_emitters["PARENT CO. PERCENT OWNERSHIP"] / 100 
join_suppliers["PARENT EMISSIONS AMT"] = join_suppliers['Emissions (tCO2e)'] * join_suppliers["PARENT CO. PERCENT OWNERSHIP"] / 100 
summary_e = join_emitters.groupby("PARENT COMPANY NAME")[["PARENT EMISSIONS AMT"]].agg(['sum', 'count'])
summary_s = join_suppliers.groupby("PARENT COMPANY NAME")[["PARENT EMISSIONS AMT"]].agg(['sum', 'count'])

# %%
len(set(join_emitters["PARENT COMPANY NAME"]))
# Out:
# 2941

# %%
join_emitters
# Out:
#                                                    Name 2017 NAICS Code  \
# 1000001                 PSE Ferndale Generating Station          221112
# 1000002                     Ardagh Glass Inc. (Dunkirk)          327213
# 1000003                   Ardagh Glass Inc. (Henderson)          327213
# 1000005                      Ardagh Glass Inc. (Madera)          327213
# 1000007  AMERICAN GYPSUM - BERNALILLO (WALLBOARD) PLANT          327420
# ...                                                 ...             ...
# 1014015                             Cedar Grove #2 Mine          212112
# 1014021                                Peco Foods, Inc.          311615
# 1014023                            JSW Steel (USA) Inc.          331110
# 1014024                 TITUS OIL & GAS PRODUCTION, LLC          211120
# 1014028                   Clean Harbors Deer Park, LLC.          562211
#
#          Emissions (tCO2e)                                   2017 NAICS Title  \
# 1000001         509154.612             Fossil Fuel Electric Power Generation
# 1000002         113519.804                     Glass Container Manufacturing
# 1000003          81110.872                     Glass Container Manufacturing
# 1000005          79854.076                     Glass Container Manufacturing
# 1000007          14084.496                       Gypsum Product Manufacturing
# ...                    ...                                                ...
# 1014015          19219.500                Bituminous Coal Underground Mining
# 1014021          87368.842                                Poultry Processing
# 1014023          43100.388  Iron and Steel Mills and Ferroalloy Manufactur...
# 1014024          53440.912                        Crude Petroleum Extraction
# 1014028          27182.524            Hazardous Waste Treatment and Disposal
#
#          FRS ID (FACILITY)  REPORTING YEAR  \
# 1000001       1.100005e+11            2020
# 1000002       1.100412e+11            2020
# 1000003       1.100015e+11            2020
# 1000005       1.100005e+11            2020
# 1000007       1.100070e+11            2020
# ...                    ...             ...
# 1014015                NaN            2020
# 1014021       1.100674e+11            2020
# 1014023       1.100007e+11            2020
# 1014024                NaN            2020
# 1014028       1.100005e+11            2020
#
#                                           FACILITY NAME  \
# 1000001                 PSE Ferndale Generating Station
# 1000002                     Ardagh Glass Inc. (Dunkirk)
# 1000003                   Ardagh Glass Inc. (Henderson)
# 1000005                      Ardagh Glass Inc. (Madera)
# 1000007  AMERICAN GYPSUM - BERNALILLO (WALLBOARD) PLANT
# ...                                                 ...
# 1014015                             Cedar Grove #2 Mine
# 1014021                                Peco Foods, Inc.
# 1014023                            JSW Steel (USA) Inc.
# 1014024                 TITUS OIL & GAS PRODUCTION, LLC
# 1014028                   Clean Harbors Deer Park, LLC.
#
#                         FACILITY ADDRESS FACILITY CITY FACILITY STATE  \
# 1000001           5105 LAKE TERRELL ROAD      FERNDALE             WA
# 1000002             524 E. CENTER STREET       DUNKIRK             IN
# 1000003                   620 Facet Road     Henderson             NC
# 1000005    24441 AVENUE 12 & ROAD 24 1/2        MADERA             CA
# 1000007                   1000 N HILL RD    BERNALILLO             NM
# ...                                  ...           ...            ...
# 1014015  County Route 14, Rum Creek Road         Yolyn             WV
# 1014021                4114 Hwy 67 South    Pocahontas             AR
# 1014023            5200 E. McKinney Road       Baytown             TX
# 1014024    420 Throckmorton St. Ste 1150    Fort Worth             TX
# 1014028      2027 Independence Parkway S      La Porte             TX
#
#          FACILITY ZIP  FACILITY COUNTY  PARENT COMPANY NAME  \
# 1000001         98248   WHATCOM COUNTY   PUGET HOLDINGS LLC
# 1000002         47336       JAY COUNTY     ARDAGH GLASS INC
# 1000003         27537     VANCE COUNTY     ARDAGH GLASS INC
# 1000005         93637    MADERA COUNTY     ARDAGH GLASS INC
# 1000007         87004  SANDOVAL COUNTY  EAGLE MATERIALS INC
# ...               ...              ...                  ...
# 1014015         25654              NaN  ARACOMA COAL CO LLC
# 1014021         72455  RANDOLPH COUNTY       PECO FOODS INC
# 1014023         77523  CHAMBERS COUNTY    JSW STEEL USA INC
# 1014024         76102              NaN      TITUS OIL & GAS
# 1014028         77571    HARRIS COUNTY    CLEAN HARBORS INC
#
#                PARENT CO. STREET ADDRESS PARENT CO. CITY PARENT CO. STATE  \
# 1000001                     PO Box 97034        Bellevue               WA
# 1000002               1209 Orange Street      Wilmington               DE
# 1000003               1209 Orange Street      Wilmington               DE
# 1000005               1209 Orange Street      Wilmington               DE
# 1000007    5960 Berkshire Lane Suite 800          Dallas               TX
# ...                                  ...             ...              ...
# 1014015                      PO Box 1098          Holden               WV
# 1014021              1101 Greensboro Ave      Tuscaloosa               AL
# 1014023          5200 East McKinney Road         Baytown               TX
# 1014024  420 Throckmorton St, Suite 1150      Fort Worth               TX
# 1014028                    P.O. Box 9149         Norwell               MA
#
#         PARENT CO. ZIP  PARENT CO. PERCENT OWNERSHIP  FACILITY NAICS CODE  \
# 1000001          98009                         100.0               221112
# 1000002          19801                         100.0               327213
# 1000003          19801                         100.0               327213
# 1000005          19801                         100.0               327213
# 1000007          75225                         100.0               327420
# ...                ...                           ...                  ...
# 1014015          25625                         100.0               212112
# 1014021          35401                         100.0               311615
# 1014023          77520                         100.0               331110
# 1014024          76102                         100.0               211120
# 1014028           2051                         100.0               562211
#
#          PARENT EMISSIONS AMT
# 1000001            509154.612
# 1000002            113519.804
# 1000003             81110.872
# 1000005             79854.076
# 1000007             14084.496
# ...                       ...
# 1014015             19219.500
# 1014021             87368.842
# 1014023             43100.388
# 1014024             53440.912
# 1014028             27182.524
#
# [8487 rows x 20 columns]

# %%
uniqueEmitters = list(set(join_emitters["PARENT COMPANY NAME"]))

# %%
def getStock(search_term):
    results = []
    query = requests.get(f'https://yfapi.net/v6/finance/autocomplete?region=IN&lang=en&query={search_term}', 
    headers={
        'accept': 'application/json',
        'X-API-KEY': '67OTHABAMI9EcpD7FKoMbHerxF8yNY35fPHdU5mc'
    })
    response = query.json()
    for i in response['ResultSet']['Result']:
        final = i['symbol']
        results.append(final)
    
    symbol = None
        
    try:
        stock = yf.Ticker(results[0])
        price = stock.info["regularMarketPrice"]
        full_name = stock.info['longName']
        curreny = stock.info["currency"]
        symbol = stock.info["symbol"]
    except Exception as e:
        pass
        # print('Something went wrong')
        # print(e)
        
    return stock.info

# %%
ticker = {}

# %%
success = 0
fail = 0

for i in range(1, 10):
    company = uniqueEmitters[i].replace('LLC', '').replace('INC', '')
    
    try:
        info = getStock(company)
        ticker[company] = info
        success += 1
    except Exception as e:
        print('Failed On: ', company)
        fail += 1
    
    print('Success: ', success, 'Fail: ', fail)
# Out:
# Something went wrong
# list index out of range
# Failed On:  SANTEE PRINT WORKS
# Success:  0 Fail:  1
# Success:  1 Fail:  1
# Something went wrong
# list index out of range
# Failed On:  UNIVERSITY OF ROCHESTER
# Success:  1 Fail:  2
# Success:  2 Fail:  2
# Something went wrong
# list index out of range
# Failed On:  KERN FRONT COGENERATION PL
# Success:  2 Fail:  3
# Something went wrong
# list index out of range
# Failed On:  SOUTHWEST GENERATION OPERATING CO
# Success:  2 Fail:  4
# Something went wrong
# list index out of range
# Failed On:  USA ENERGY GROUP
# Success:  2 Fail:  5
# Something went wrong
# list index out of range
# Failed On:  SIERRA PACIFIC CORP
# Success:  2 Fail:  6
# Something went wrong
# list index out of range
# Failed On:  SOLID WASTE AUTHORITY OF CENTRAL OHIO
# Success:  2 Fail:  7

# %%
getStock('SIERRA PACIFIC')
# Out:
# Something went wrong
# list index out of range
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /var/folders/k9/zh0llzl502j89h_jjzdtdllh0000gn/T/ipykernel_66300/2826848658.py in <module>
# ----> 1 getStock('SIERRA PACIFIC')
#
# /var/folders/k9/zh0llzl502j89h_jjzdtdllh0000gn/T/ipykernel_66300/2284506529.py in getStock(search_term)
#      23         print(e)
#      24
# ---> 25     return stock.info
#
# UnboundLocalError: local variable 'stock' referenced before assignment
